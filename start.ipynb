# %%
# %ls -l --group-directories-first
# Out:
# total 2531320
# drwxr-xr-x 4 root root       4096 May  1 19:24 data/
# drwxr-xr-x 4 root root       4096 May  1 19:18 models/
# drwxr-xr-x 2 root root       4096 May  1 19:27 __pycache__/
# drwxr-xr-x 3 root root       4096 May  1 20:48 utils/
# drwxr-xr-x 2 root root       4096 May  1 19:29 weights/
# -rw-r--r-- 1 root root        146 May  1 19:18 constants.py
# -rw-r--r-- 1 root root 2592010240 Jun 27  2009 indoorCVPR_09.tar
# -rw-r--r-- 1 root root       2294 May  1 19:19 prepare_data.py
# -rw-r--r-- 1 root root        260 May  1 19:18 README.md
# -rw-r--r-- 1 root root          0 May  1 19:18 requirements.txt
# -rw-r--r-- 1 root root       1126 May  1 19:18 start.ipynb
# -rw-r--r-- 1 root root       9815 May  1 19:18 tf2_train.ipynb
# -rw-r--r-- 1 root root       5742 May  1 20:48 train.py

# %%
# !git clone https://github.com/sergevkim/ReflectionSeparation.git
# Out:
# Cloning into 'ReflectionSeparation'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 117 (delta 41), reused 94 (delta 21), pack-reused 0
# Receiving objects: 100% (117/117), 58.83 MiB | 27.16 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/sergevkim/ReflectionSeparation
#    ae9a89c..225b3ad  colab      -> origin/colab
# Updating ae9a89c..225b3ad
# Fast-forward
#  utils/args.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd ReflectionSeparation
# !git checkout colab
# Out:
# /content/ReflectionSeparation
# Branch 'colab' set up to track remote branch 'colab' from 'origin'.
# Switched to a new branch 'colab'

# %%
# !wget http://groups.csail.mit.edu/vision/LabelMe/NewImages/indoorCVPR_09.tar
# Out:
# --2020-05-01 19:20:25--  http://groups.csail.mit.edu/vision/LabelMe/NewImages/indoorCVPR_09.tar
# Resolving groups.csail.mit.edu (groups.csail.mit.edu)... 128.30.2.44
# Connecting to groups.csail.mit.edu (groups.csail.mit.edu)|128.30.2.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2592010240 (2.4G) [application/x-tar]
# Saving to: ‘indoorCVPR_09.tar’
#
# indoorCVPR_09.tar   100%[===================>]   2.41G  9.14MB/s    in 3m 12s
#
# 2020-05-01 19:23:38 (12.8 MB/s) - ‘indoorCVPR_09.tar’ saved [2592010240/2592010240]

# %%
# !python prepare_data.py
# Out:
# 67it [00:00, 134.90it/s]
# 100% 2796/2796 [02:29<00:00, 18.74it/s]

# %%
# !python train.py --help
# Out:
# usage: train.py [-h] [--model MODEL] [--batch-size BATCH_SIZE]
#                 [--n-epochs N_EPOCHS] [--disable-cuda] [--save-model]
#                 [--verbose] [--subject-images-path SUBJECT_IMAGES_PATH]
#                 [--astigma-images-path ASTIGMA_IMAGES_PATH]
#                 [--weights-path WEIGHTS_PATH] [--logs-path LOGS_PATH]
#                 [--from-checkpoint FROM_CHECKPOINT]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --model MODEL         model type, default: unet
#   --batch-size BATCH_SIZE
#                         batch_size, default: 2
#   --n-epochs N_EPOCHS   number of epochs, default: 10
#   --disable-cuda        disable CUDA
#   --save-model          save model
#   --verbose             verbose
#   --subject-images-path SUBJECT_IMAGES_PATH
#                         subject images path
#   --astigma-images-path ASTIGMA_IMAGES_PATH
#                         astigma images path
#   --weights-path WEIGHTS_PATH
# ...

# %%
# !python train.py --verbose --save-model --from-checkpoint="" --batch-size=32
# Out:
# ====ARGS====
# model: unet
# batch_size: 32
# n_epochs: 10
# disable_cuda: False
# save_model: True
# verbose: True
# subject_images_path: /content/ReflectionSeparation/data/subject_images
# astigma_images_path: /content/ReflectionSeparation/data/astigma_images
# weights_path: /content/ReflectionSeparation/weights
# logs_path: /content/ReflectionSeparation/logs
# from_checkpoint:
# ...
# CUDA is on
# 100% 15475/15475 [01:26<00:00, 178.68it/s]
# 100% 2796/2796 [00:32<00:00, 86.49it/s]
# There are 123520 subject and 44736 astigma files
# 0
# 0 0 {'mse_transmission': 0.14850138127803802, 'mse_reflection': 0.011557158082723618}
# 0 100 {'mse_transmission': 0.020901134237647057, 'mse_reflection': 0.005348573438823223}
# 0 200 {'mse_transmission': 0.013708657585084438, 'mse_reflection': 0.0034451026003807783}
# 0 300 {'mse_transmission': 0.01194145530462265, 'mse_reflection': 0.00286454102024436}
# 0 400 {'mse_transmission': 0.0160154327750206, 'mse_reflection': 0.005884767975658178}
# ...

# %%
# !python train.py --verbose --save-model --from-checkpoint="./weights/unet_v5_e0.hdf5" --batch-size=32
# Out:
# ====ARGS====
# model: unet
# batch_size: 32
# n_epochs: 10
# disable_cuda: False
# save_model: True
# verbose: True
# subject_images_path: /content/ReflectionSeparation/data/subject_images
# astigma_images_path: /content/ReflectionSeparation/data/astigma_images
# weights_path: /content/ReflectionSeparation/weights
# logs_path: /content/ReflectionSeparation/logs
# from_checkpoint: ./weights/unet_v5_e0.hdf5
# ...
# CUDA is on
# 100% 15475/15475 [01:26<00:00, 177.95it/s]
# 100% 2796/2796 [00:33<00:00, 84.46it/s]
# There are 123520 subject and 44736 astigma files
# 0
# 0 0 {'mse_transmission': 0.006410319358110428, 'mse_reflection': 0.00232154643163085}
# 0 100 {'mse_transmission': 0.006421416997909546, 'mse_reflection': 0.003117635380476713}
# Traceback (most recent call last):
#   File "train.py", line 147, in <module>
#     main()
#   File "train.py", line 137, in main
#     train(args, model, device, train_loader_a, train_loader_b, optimizer, epoch)
#   File "train.py", line 30, in train
# ...

# %%
# !python train.py --verbose --save-model --weights-path="../drive/My Drive/" --from-checkpoint="./weights/unet_v5_e0.hdf5" --batch-size=32
# Out:
# ====ARGS====
# model: unet
# batch_size: 32
# n_epochs: 10
# disable_cuda: False
# save_model: True
# verbose: True
# subject_images_path: /content/ReflectionSeparation/data/subject_images
# astigma_images_path: /content/ReflectionSeparation/data/astigma_images
# weights_path: ../drive/My Drive/
# logs_path: /content/ReflectionSeparation/logs
# from_checkpoint: ./weights/unet_v5_e0.hdf5
# ...
# CUDA is on
# 100% 15475/15475 [01:28<00:00, 175.01it/s]
# 100% 2796/2796 [00:33<00:00, 83.72it/s]
# There are 123520 subject and 44736 astigma files
# 0
# 0 0 {'mse_transmission': 0.008962775580585003, 'mse_reflection': 0.004212203435599804}
# 0 100 {'mse_transmission': 0.007922052405774593, 'mse_reflection': 0.0035674755927175283}
# 0 200 {'mse_transmission': 0.006533380132168531, 'mse_reflection': 0.0036809854209423065}
# 0 300 {'mse_transmission': 0.007659306284040213, 'mse_reflection': 0.00244167004711926}
# 0 400 {'mse_transmission': 0.007059548050165176, 'mse_reflection': 0.00268431194126606}
# ...
